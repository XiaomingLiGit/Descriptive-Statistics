# %%
# Q1–Q4: Create variables and inspect their data types

trip_id = 101
distance_km = 8.5
zone = "Downtown"
completed = True

print(trip_id)
print(distance_km)
print(zone)
print(completed)

print(type(trip_id))
print(type(distance_km))
print(type(zone))
print(type(completed))
# Out:
# 101
# 8.5
# Downtown
# True
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
# Q5: Convert a float to an integer

duration_min = 22.5

duration_integer = int(duration_min)

print(duration_min)
print(duration_integer)

# 22.5 becomes 22 — the decimal part is removed.
# Out:
# 22.5
# 22

# %%
# Q6: Convert a string to a numeric value

fare = "25.50"

print(type(fare))

fare = float(fare)

print(fare)
print(type(fare))
# Out:
# <class 'str'>
# 25.5
# <class 'float'>

# %% [markdown]
# # Part B — Arithmetic and Comparisons

# %%
distance_km = 12
duration_min = 30
fare = 28.50
wait_min = 8

# %%
# Q7: Fare per kilometre

fare_per_km = fare / distance_km

print(fare_per_km)
# Out:
# 2.375

# %%
# Q8: Average speed in km/h

duration_hr = duration_min / 60

speed_kmh = distance_km / duration_hr

print(speed_kmh)
# Out:
# 24.0

# %%
# Q9: Increase fare by 15%

new_fare = fare * 1.15

print(new_fare)
# Out:
# 32.775

# %%
# Q10: Is the trip longer than 10 km?

print(distance_km > 10)
# Out:
# True

# %%
# Q11: Is the waiting time at least 10 minutes?

print(wait_min >= 10)
# Out:
# False

# %%
# Q12: Is fare between $20 and $40?

print((fare >= 20) and (fare <= 40))
# Out:
# True

# %%
# Q13: Create a Boolean variable

long_trip = distance_km > 10

print(long_trip)
# Out:
# True

# %% [markdown]
# # Part C — Lists

# %%
wait_times = [4.2, 8.5, 6.1, 12.3, 5.6, 9.8]

# %%
# Q14: First waiting time

print(wait_times[0])
# Out:
# 4.2

# %%
# Q15: Last waiting time

print(wait_times[-1])

# %%
# Q16: Number of observations

print(len(wait_times))

# %%
# Q17: Total waiting time

print(sum(wait_times))

# %%
# Q18: Average waiting time without NumPy or pandas

average_wait = sum(wait_times) / len(wait_times)

print(average_wait)

# %%
# Q19: Minimum and maximum

print("Minimum:", min(wait_times))
print("Maximum:", max(wait_times))

# %%
# Q20: Add another waiting time

wait_times.append(7.4)

print(wait_times)

# %%
# Q21: Count waiting times > 8

count = 0

for x in wait_times:
    if x > 8:
        count += 1

print("Number of waits > 8:", count)

# %% [markdown]
# # Part C2 — Dictionaries

# %%
trip = {
    "trip_id": 101,
    "zone": "Airport",
    "distance_km": 18.5,
    "wait_min": 11.2,
    "fare": 42.5
}

# %%
# Q22: Retrieve zone

print(trip["zone"])

# %%
# Q23: Retrieve fare

print(trip["fare"])

# %%
# Q24: Add payment type

trip["payment_type"] = "Card"

print(trip)

# %%
# Q25: Update waiting time

trip["wait_min"] = 10.5

print(trip)

# %%
# Q26: Fare per kilometre

fare_per_km = trip["fare"] / trip["distance_km"]

print(fare_per_km)

# %%
# Q27: Print a sentence using dictionary values

print(
    f"Trip {trip['trip_id']} started at {trip['zone']} "
    f"and cost ${trip['fare']}."
)

# %% [markdown]
# # Part D — Boolean Logic and if Statements

# %%
wait_min = 12
zone = "Airport"
fare = 38
status = "completed"

# %%
# Q28: AND

print((wait_min > 10) and (zone == "Airport"))

# %%
# Q29: OR

print((fare > 50) or (wait_min > 10))

# %%
# Q30: NOT cancelled

print(status != "cancelled")

# %%
# Q31: Long wait or acceptable wait

if wait_min > 10:
    print("Long wait")
else:
    print("Acceptable wait")

# %%
# Q32: Short / Medium / Long

if wait_min < 5:
    print("Short")
elif wait_min <= 10:
    print("Medium")
else:
    print("Long")

# %%
# Q33: Airport service issue

if (wait_min > 10) and (zone == "Airport"):
    print("Airport service issue")
else:
    print("No airport service issue")

# %% [markdown]
# # Part E — Loops

# %%
wait_times = [4.2, 8.5, 6.1, 12.3, 5.6, 15.2]

# %%
# Q34: Print every waiting time

for x in wait_times:
    print(x)

# %%
# Q35: Print only waits > 10

for x in wait_times:
    if x > 10:
        print(x)

# %%
# Q36: Count waits > 10

count = 0

for x in wait_times:
    if x > 10:
        count += 1

print(count)

# %%
# Q37: Create a new list of long waits

long_waits = []

for x in wait_times:
    if x > 10:
        long_waits.append(x)

print(long_waits)

# %%
# Q38: Calculate the total using a loop

total = 0

for x in wait_times:
    total = total + x

print(total)

# %%
# Q39: Calculate the mean manually

mean_wait = total / len(wait_times)

print(mean_wait)

# %% [markdown]
# # Part E2 — Functions

# %%
# Q40: Waiting-time category

def wait_category(wait_min):
    if wait_min < 5:
        return "short"
    elif wait_min < 10:
        return "medium"
    else:
        return "long"


print(wait_category(3))
print(wait_category(7))
print(wait_category(15))
# Out:
# short
# medium
# long

# %%
# Q41: Fare per kilometre function

def fare_per_km(fare, distance):
    return fare / distance


print(fare_per_km(30, 10))

# %%
# Q42: Long-wait function

def is_long_wait(wait_min):
    return wait_min > 10


print(is_long_wait(8))
print(is_long_wait(15))

# %%
# Q43: Trip cost after tax

def trip_cost(base_fare, tax_rate):
    return base_fare * (1 + tax_rate)


print(trip_cost(25, 0.15))

# %%
# Q44: Average speed

def speed_kmh(distance_km, duration_min):
    duration_hr = duration_min / 60
    return distance_km / duration_hr


print(speed_kmh(15, 30))

# %%
# Q45: Protect against zero duration

def speed_kmh(distance_km, duration_min):

    if duration_min == 0:
        return "Invalid duration"

    duration_hr = duration_min / 60

    return distance_km / duration_hr


print(speed_kmh(15, 30))
print(speed_kmh(15, 0))

# %%
# Q46: Apply a function to every waiting time

wait_times = [4.2, 8.5, 6.1, 12.3, 5.6, 15.2]

for x in wait_times:
    print(x, wait_category(x))

# %% [markdown]
# # Part F — Lambda Expressions

# %%
# Q47: Normal function

def double(x):
    return x * 2


print(double(5))

# %%
# Same function using lambda

double = lambda x: x * 2

print(double(5))

# %%
# Q48: Square of a number

square = lambda x: x ** 2

print(square(5))

# %%
# Q49: Waiting-time classification

wait_label = lambda x: "Long" if x > 10 else "Normal"

print(wait_label(6))
print(wait_label(15))

# %%
# Q50: Compare def and lambda

def wait_label_function(x):
    if x > 10:
        return "Long"
    else:
        return "Normal"


wait_label_lambda = lambda x: "Long" if x > 10 else "Normal"

print(wait_label_function(12))
print(wait_label_lambda(12))

# %%
def wait_category(wait_min):
    if wait_min < 5:
        return "Short"
    elif wait_min <= 10:
        return "Medium"
    else:
        return "Long"
