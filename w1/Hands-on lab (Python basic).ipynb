# %%
# Q1–Q4: Create variables and inspect their data types

trip_id = 101
distance_km = 8.5
zone = "Downtown"
completed = True

print(trip_id)
print(distance_km)
print(zone)
print(completed)

print(type(trip_id))
print(type(distance_km))
print(type(zone))
print(type(completed))
# Out:
# 101
# 8.5
# Downtown
# True
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
